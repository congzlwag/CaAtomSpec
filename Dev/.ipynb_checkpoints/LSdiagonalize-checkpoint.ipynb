# %%
from numpy import *
from matplotlib import pyplot as plt
# %matplotlib nbagg

# %%
from sys import path
path.append("./Numerov")

# %%
from scipy.linalg import eigh

# %%
from specPreProcess import hc_in_eVcm, eV_in_au

# %% [markdown]
# Now in LS.py dx=5e-3

# %%
# %run LS.py
# Out:
# Row 0: 0mat.entry [00:00, ?mat.entry/s]
# 16 states in the subspace of (L,mL)=(0,0), (S,mS)=(0,0) are relevant
# e config. [(3, 2, 3, 2), (3, 2, 4, 2), (3, 2, 5, 2), (4, 0, 4, 0), (4, 0, 5, 0), (4, 1, 4, 1), (4, 1, 5, 1), (4, 2, 4, 2), (4, 2, 5, 2), (4, 3, 4, 3), (4, 3, 5, 3), (5, 0, 5, 0), (5, 1, 5, 1), (5, 2, 5, 2), (5, 3, 5, 3), (5, 4, 5, 4)]
# Row 0: 16mat.entry [00:12,  1.27mat.entry/s]
# Row 1: 15mat.entry [00:13,  1.08mat.entry/s]
# Row 2: 14mat.entry [00:12,  1.01s/mat.entry]
# Row 3: 13mat.entry [00:05,  2.56mat.entry/s]
# Row 4: 12mat.entry [00:05,  2.13mat.entry/s]
# Row 5: 11mat.entry [00:08,  1.32mat.entry/s]
# Row 6: 10mat.entry [00:08,  1.20mat.entry/s]
# Row 7: 9mat.entry [00:10,  1.15s/mat.entry]
# Row 8: 8mat.entry [00:10,  1.33s/mat.entry]
# Row 9: 7mat.entry [00:09,  1.53s/mat.entry]
# Row 10: 6mat.entry [00:08,  1.61s/mat.entry]
# Row 11: 5mat.entry [00:02,  2.02mat.entry/s]
# Row 12: 4mat.entry [00:03,  1.11mat.entry/s]
# ...

# %%
ground._Energy
# Out:
# -0.6593285008462739

# %%
ground.defineBasis_LSrestricted((0,10),(3,6),(3,6))

# %%
ground.displayBasis()
# Out:
# 16 states in the subspace of (L,mL)=(0,0), (S,mS)=(0,0) are relevant
# e config. [(3, 2, 3, 2), (3, 2, 4, 2), (3, 2, 5, 2), (4, 0, 4, 0), (4, 0, 5, 0), (4, 1, 4, 1), (4, 1, 5, 1), (4, 2, 4, 2), (4, 2, 5, 2), (4, 3, 4, 3), (4, 3, 5, 3), (5, 0, 5, 0), (5, 1, 5, 1), (5, 2, 5, 2), (5, 3, 5, 3), (5, 4, 5, 4)]

# %%
ground.V_mat_construct()
# Out:
# Row 0: 16mat.elem. [00:03,  4.51mat.elem./s]
# Row 1: 15mat.elem. [00:03,  4.20mat.elem./s]
# Row 2: 14mat.elem. [00:02,  3.97mat.elem./s]
# Row 3: 13mat.elem. [00:01, 11.84mat.elem./s]
# Row 4: 12mat.elem. [00:01, 10.57mat.elem./s]
# Row 5: 11mat.elem. [00:01,  5.41mat.elem./s]
# Row 6: 10mat.elem. [00:01,  4.76mat.elem./s]
# Row 7: 9mat.elem. [00:02,  3.53mat.elem./s]
# Row 8: 8mat.elem. [00:02,  3.11mat.elem./s]
# Row 9: 7mat.elem. [00:02,  2.59mat.elem./s]
# Row 10: 6mat.elem. [00:02,  2.41mat.elem./s]
# Row 11: 5mat.elem. [00:00,  9.31mat.elem./s]
# Row 12: 4mat.elem. [00:00,  4.64mat.elem./s]
# Row 13: 3mat.elem. [00:01,  2.93mat.elem./s]
# Row 14: 2mat.elem. [00:01,  1.98mat.elem./s]
# Row 15: 1mat.elem. [00:00,  1.51mat.elem./s]
# array([[ 1.53860926e-01, -3.32564408e-02,  1.77050924e-02,
#          2.06038268e-02, -7.00568609e-03, -2.53082833e-02,
#          1.00895682e-02,  1.51428891e-02, -9.09370540e-03,
#         -4.91086238e-03,  3.76433722e-03,  3.39062181e-03,
# ...

# %%
Vmat5e_3 = _

# %% [markdown]
# Now in LS.py dx=1e-2

# %%
# %run LS.py

# %%
ground.defineBasis_LSrestricted((0,3),(3,7),(3,7))

# %%
ground.displayBasis()
# Out:
# 22 states in the subspace of (L,mL)=(0,0), (S,mS)=(0,0) are relevant
# e config. [(3, 2, 3, 2), (3, 2, 4, 2), (3, 2, 5, 2), (3, 2, 6, 2), (4, 0, 4, 0), (4, 0, 5, 0), (4, 0, 6, 0), (4, 1, 4, 1), (4, 1, 5, 1), (4, 1, 6, 1), (4, 2, 4, 2), (4, 2, 5, 2), (4, 2, 6, 2), (5, 0, 5, 0), (5, 0, 6, 0), (5, 1, 5, 1), (5, 1, 6, 1), (5, 2, 5, 2), (5, 2, 6, 2), (6, 0, 6, 0), (6, 1, 6, 1), (6, 2, 6, 2)]

# %%
ground.V_mat_construct()
# Out:
# Row 0: 22mat.elem. [00:03,  5.39mat.elem./s]
# Row 1: 21mat.elem. [00:04,  4.94mat.elem./s]
# Row 2: 20mat.elem. [00:04,  4.37mat.elem./s]
# Row 3: 19mat.elem. [00:03,  4.24mat.elem./s]
# Row 4: 18mat.elem. [00:01, 11.55mat.elem./s]
# Row 5: 17mat.elem. [00:01, 10.00mat.elem./s]
# Row 6: 16mat.elem. [00:01,  9.60mat.elem./s]
# Row 7: 15mat.elem. [00:02,  5.70mat.elem./s]
# Row 8: 14mat.elem. [00:02,  5.15mat.elem./s]
# Row 9: 13mat.elem. [00:02,  4.88mat.elem./s]
# Row 10: 12mat.elem. [00:02,  4.12mat.elem./s]
# Row 11: 11mat.elem. [00:02,  3.70mat.elem./s]
# Row 12: 10mat.elem. [00:02,  3.55mat.elem./s]
# Row 13: 9mat.elem. [00:00,  9.35mat.elem./s]
# Row 14: 8mat.elem. [00:00,  8.51mat.elem./s]
# Row 15: 7mat.elem. [00:01,  4.73mat.elem./s]
# Row 16: 6mat.elem. [00:01,  3.98mat.elem./s]
# Row 17: 5mat.elem. [00:01,  3.33mat.elem./s]
# Row 18: 4mat.elem. [00:01,  2.60mat.elem./s]
# Row 19: 3mat.elem. [00:00,  7.86mat.elem./s]
# Row 20: 2mat.elem. [00:00,  4.23mat.elem./s]
# ...

# %%
Vmat1e_2 = _.copy()

# %%
plt.matshow(Vmat1e_2)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="480">

# %%
ax = plt.subplot(121)
ax.matshow(Vmat5e_3)
ax = plt.subplot(122)
ax.matshow(Vmat1e_2)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4dfea4187716> in <module>()
#       1 ax = plt.subplot(121)
# ----> 2 ax.matshow(Vmat5e_3)
#       3 ax = plt.subplot(122)
#       4 ax.matshow(Vmat1e_2)
#
# NameError: name 'Vmat5e_3' is not defined

# %%
linalg.norm(Vmat1e_2- Vmat5e_3)
# Out:
# 0.0008738954401324798

# %%
linalg.norm(Vmat5e_3)
# Out:
# 0.26568631089261957

# %%
_21/_22
# Out:
# 0.003289200099156315

# %% [markdown]
# Since the precision of dx=1e-2 is acceptable, keep that henceforth

# %%
H, S = ground.before_diagonalize()

# %%
Vmat1e_2[ground.idx_in_relev_basis,ground.idx_in_relev_basis], ground._Energy_unperturb, H[ground.idx_in_relev_basis,ground.idx_in_relev_basis]
# Out:
# (0.25692844146323746, -0.8725552415925876, -0.6156268001293501)

# %%
plt.matshow(S - identity(S.shape[0]))
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="480">

# %%
abs(S-identity(S.shape[0])).max()
# Out:
# 0.04321220708441087

# %%
[x.e_config for x in ground.relevant_basis[3:6]]
# Out:
# [(3, 2, 6, 2), (4, 0, 4, 0), (4, 0, 5, 0)]

# %%
uInnerProd_1d(*request_ur(4,0),*request_ur(5,0))
# Out:
# -0.030555644659424275

# %%
u,r = request_ur(4,0)
plt.plot(r**0.5,u)
u,r = request_ur(5,0)
plt.plot(r**0.5,u)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
w,v=eigh(H,b=S)

# %%
w
# Out:
# array([-0.67945896, -0.51266062, -0.46515591, -0.41859826, -0.41574058,
#        -0.39847498, -0.38353762, -0.35472741, -0.30054862, -0.25391774,
#        -0.22734988, -0.22060584, -0.20067447, -0.18862757, -0.16651961,
#        -0.15092633, -0.13891492, -0.12334444, -0.10219091, -0.09904913,
#        -0.0807341 , -0.02099487])

# %%
ground.idx_in_relev_basis
# Out:
# 4

# %%
plt.matshow(exp(abs(v)))
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="480">

# %%
np.argmax(abs(v[ground.idx_in_relev_basis]))
# Out:
# 0

# %%
w[np.argmax(abs(v[ground.idx_in_relev_basis]))]
# Out:
# -0.6794589596599278

# %%
ground._Energy_unperturb
# Out:
# -0.8725552415925876

# %%
ground.V_mat[ground.idx_in_relev_basis,ground.idx_in_relev_basis]
# Out:
# 0.0408914314797709

# %%
Vmat1e_2[ground.idx_in_relev_basis, ground.idx_in_relev_basis]
# Out:
# -0.8316638101128166

# %%
_44 / eV_in_au / hc_in_eVcm
# Out:
# -184094.56052328937

# %%
49305.96+95751.87
# Out:
# 145057.83

# %%
-_*hc_in_eVcm*eV_in_au
# Out:
# -0.660932104514233

# %%
-(49305.96+95751.87-23652.304)*hc_in_eVcm*eV_in_au
# Out:
# -0.5531642779906292

# %%
w
# Out:
# array([-0.83766933, -0.62261571, -0.57370159, -0.46096039, -0.38228476,
#        -0.32148324, -0.28898427, -0.26495514, -0.20957652, -0.19100648,
#        -0.17013188, -0.14385088, -0.08114704])

# %%
# %run LS.py
# Out:
# Row 0: 0mat.entry [00:00, ?mat.entry/s]
# 16 states in the subspace of (L,mL)=(0,0), (S,mS)=(0,0) are relevant
# e config. [(3, 2, 3, 2), (3, 2, 4, 2), (3, 2, 5, 2), (4, 0, 4, 0), (4, 0, 5, 0), (4, 1, 4, 1), (4, 1, 5, 1), (4, 2, 4, 2), (4, 2, 5, 2), (4, 3, 4, 3), (4, 3, 5, 3), (5, 0, 5, 0), (5, 1, 5, 1), (5, 2, 5, 2), (5, 3, 5, 3), (5, 4, 5, 4)]
# Row 0: 16mat.entry [00:11,  1.36mat.entry/s]
# Row 1: 15mat.entry [00:12,  1.20mat.entry/s]
# Row 2: 14mat.entry [00:11,  1.09mat.entry/s]
# Row 3: 13mat.entry [00:04,  2.83mat.entry/s]
# Row 4: 12mat.entry [00:04,  2.53mat.entry/s]
# Row 5: 11mat.entry [00:07,  1.45mat.entry/s]
# Row 6: 10mat.entry [00:07,  1.31mat.entry/s]
# Row 7: 9mat.entry [00:08,  1.02mat.entry/s]
# Row 8: 8mat.entry [00:08,  1.11s/mat.entry]
# Row 9: 7mat.entry [00:08,  1.28s/mat.entry]
# Row 10: 6mat.entry [00:07,  1.48s/mat.entry]
# Row 11: 5mat.entry [00:02,  2.25mat.entry/s]
# Row 12: 4mat.entry [00:03,  1.19mat.entry/s]
# ...

# %% [markdown]
# First excited state

# %%
# %run LS.py

# %%
excite1 = LS2eState((4,0,4,1),1,1,0,0)

# %%
excite1.defineBasis_LSrestricted((0,5),(3,6),(3,6))

# %%
excite1.displayBasis()
# Out:
# 23 states in the subspace of (L,mL)=(1,1), (S,mS)=(0,0) are relevant
# e config. [(3, 2, 4, 1), (3, 2, 4, 2), (3, 2, 4, 3), (3, 2, 5, 1), (3, 2, 5, 2), (3, 2, 5, 3), (4, 0, 4, 1), (4, 0, 5, 1), (4, 1, 4, 2), (4, 1, 5, 0), (4, 1, 5, 1), (4, 1, 5, 2), (4, 2, 4, 3), (4, 2, 5, 1), (4, 2, 5, 2), (4, 2, 5, 3), (4, 3, 5, 2), (4, 3, 5, 3), (4, 3, 5, 4), (5, 0, 5, 1), (5, 1, 5, 2), (5, 2, 5, 3), (5, 3, 5, 4)]

# %%
w,v = excite1.diagonalize()
# Out:
# Row 0: 23mat.entry [00:19,  1.15s/mat.entry]
# Row 1: 22mat.entry [00:06,  3.53mat.entry/s]
# Row 2: 21mat.entry [00:22,  1.49s/mat.entry]
# Row 3: 20mat.entry [00:16,  1.14s/mat.entry]
# Row 4: 19mat.entry [00:05,  3.63mat.entry/s]
# Row 5: 18mat.entry [00:23,  1.85s/mat.entry]
# Row 6: 17mat.entry [00:09,  1.56mat.entry/s]
# Row 7: 16mat.entry [00:09,  1.43mat.entry/s]
# Row 8: 15mat.entry [00:14,  1.26s/mat.entry]
# Row 9: 14mat.entry [00:07,  1.46mat.entry/s]
# Row 10: 13mat.entry [00:03,  4.10mat.entry/s]
# Row 11: 12mat.entry [00:14,  1.38s/mat.entry]
# Row 12: 11mat.entry [00:16,  1.82s/mat.entry]
# Row 13: 10mat.entry [00:11,  1.41s/mat.entry]
# Row 14: 9mat.entry [00:03,  2.49mat.entry/s]
# Row 15: 8mat.entry [00:14,  2.10s/mat.entry]
# Row 16: 7mat.entry [00:11,  2.01s/mat.entry]
# Row 17: 6mat.entry [00:02,  1.23mat.entry/s]
# Row 18: 5mat.entry [00:11,  2.69s/mat.entry]
# Row 19: 4mat.entry [00:03,  1.22mat.entry/s]
# Row 20: 3mat.entry [00:05,  1.70s/mat.entry]
# ...

# %%
plt.matshow(abs(v))
# Out:
# <img src="data:image/png;base64,..." width="480">

# %%
excite1._Energy
# Out:
# -0.5371258581008078

# %%
(excite1._Energy - ground._Energy) / eV_in_au / hc_in_eVcm
# Out:
# 26843.62391073335

# %%
-_*hc_in_eVcm*eV_in_au
# Out:
# -0.5918676258304667

# %%
23652.304 * hc_in_eVcm * eV_in_au
# Out:
# 0.10776782652360381

# %%
1/23652.304
# Out:
# 4.227917922922012e-05

# %%
# %run LS.py
# Out:
# 23 states in the subspace of (L,mL,S,mS)=(1,mL,0,mS) are relevant
# e config. [(3, 2, 4, 1), (3, 2, 4, 2), (3, 2, 4, 3), (3, 2, 5, 1), (3, 2, 5, 2), (3, 2, 5, 3), (4, 0, 4, 1), (4, 0, 5, 1), (4, 1, 4, 2), (4, 1, 5, 0), (4, 1, 5, 1), (4, 1, 5, 2), (4, 2, 4, 3), (4, 2, 5, 1), (4, 2, 5, 2), (4, 2, 5, 3), (4, 3, 5, 2), (4, 3, 5, 3), (4, 3, 5, 4), (5, 0, 5, 1), (5, 1, 5, 2), (5, 2, 5, 3), (5, 3, 5, 4)]

# %%
excite1 = LS2eState((4,0,4,1),1,1,0,0)

excite1.defineBasis_LSrestricted((0,5),(3,6),(3,6))

excite1.displayBasis()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-e424e651392f> in <module>()
# ----> 1 excite1 = LS2eState((4,0,4,1),1,1,0,0)
#       2
#       3 excite1.defineBasis_LSrestricted((0,5),(3,6),(3,6))
#       4
#       5 excite1.displayBasis()
#
# ~/Git/CaAtomSpec/Dev/LS.py in __init__(self, L, S, e_config, gamma_basis, coordinates)
#      92                 # self.mS = mS
#      93                 self.e_config = e_config
# ---> 94                 self.setGammaBasis(gamma_basis)
#      95                 self.coordinates = coordinates
#      96                 assert self.normalizationFactor(e_config) > 0
#
# ~/Git/CaAtomSpec/Dev/LS.py in setGammaBasis(self, gb)
#     104                         reset = True
#     105                 else:
# --> 106                         if gb != self.__gamma_basis:
#     107                                 idx_in_basis = None
# ...

# %%
w,v = excite1.diagonalizeLS()
# Out:
# Row 0: 23mat.entry [00:19,  1.15s/mat.entry]
# Row 1: 22mat.entry [00:05,  3.67mat.entry/s]
# Row 2: 21mat.entry [00:22,  1.47s/mat.entry]
# Row 3: 20mat.entry [00:17,  1.17s/mat.entry]
# Row 4: 19mat.entry [00:05,  3.56mat.entry/s]
# Row 5: 18mat.entry [00:21,  1.65s/mat.entry]
# Row 6: 17mat.entry [00:08,  1.58mat.entry/s]
# Row 7: 16mat.entry [00:09,  1.41mat.entry/s]
# Row 8: 15mat.entry [00:14,  1.22s/mat.entry]
# Row 9: 14mat.entry [00:07,  1.41mat.entry/s]
# Row 10: 13mat.entry [00:03,  4.09mat.entry/s]
# Row 11: 12mat.entry [00:14,  1.38s/mat.entry]
# Row 12: 11mat.entry [00:16,  1.76s/mat.entry]
# Row 13: 10mat.entry [00:11,  1.37s/mat.entry]
# Row 14: 9mat.entry [00:03,  2.58mat.entry/s]
# Row 15: 8mat.entry [00:14,  2.04s/mat.entry]
# Row 16: 7mat.entry [00:12,  2.09s/mat.entry]
# Row 17: 6mat.entry [00:02,  1.13s/mat.entry]
# Row 18: 5mat.entry [00:11,  2.72s/mat.entry]
# Row 19: 4mat.entry [00:03,  1.12mat.entry/s]
# Row 20: 3mat.entry [00:05,  1.73s/mat.entry]
# ...

# %%
excite1._EnergyLS
# Out:
# -0.5490924289650408

# %%
# %run LS.py

# %%
highR1 = LS2eState((4,0,18,0),0,0,0,0)
highR1.defineBasis_LSrestricted((0,9),(3,7),(15,20))

# %%
highR1.displayBasis()
# Out:
# 80 states in the subspace of (L,mL)=(0,0), (S,mS)=(0,0) are relevant
# ...

# %%
with open('specs/CaI.pickle','rb') as fp:
    dataI = pickle.load(fp)

# %%
dataI
# Out:
# {(0, 0): {(4, 0, 4, 0): array([(0, 0., -17.98487863, -0.6609321)],
#         dtype=[('J', '<i4'), ('spec/cm_1', '<f8'), ('energy/eV', '<f8'), ('energy/au', '<f8')]),
#   (4, 0, 5, 0): array([(0, 33317.264, -13.85406439, -0.50912748)],
#         dtype=[('J', '<i4'), ('spec/cm_1', '<f8'), ('energy/eV', '<f8'), ('energy/au', '<f8')]),
#   (4, 0, 6, 0): array([(0, 40690.435, -12.9399077, -0.47553284)],
#         dtype=[('J', '<i4'), ('spec/cm_1', '<f8'), ('energy/eV', '<f8'), ('energy/au', '<f8')]),
#   (4, 1, 4, 1): array([(0, 41786.276, -12.80404074, -0.47053982)],
#         dtype=[('J', '<i4'), ('spec/cm_1', '<f8'), ('energy/eV', '<f8'), ('energy/au', '<f8')]),
#   (4, 0, 7, 0): array([(0, 44276.538, -12.4952876, -0.45919335)],
#         dtype=[('J', '<i4'), ('spec/cm_1', '<f8'), ('energy/eV', '<f8'), ('energy/au', '<f8')]),
#   (4, 0, 8, 0): array([(0, 45887.2, -12.29559097, -0.45185464)],
# ...

# %%
grounddata = load('4s4s_trial1.npz')

# %%
ax = plt.subplot(1,2,1)
V = ax.matshow(grounddata['V'])
plt.colorbar(V)
ax.set_title(r"$V$")

ax = plt.subplot(1,2,2)
v = ax.matshow(log10(abs(grounddata['eigvecs'])))
plt.colorbar(v)
ax.set_title(r"$\log_{10}(|$eigvecs$|)$")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1.05,'$\\log_{10}(|$eigvecs$|)$')

# %%
plt.subplots_adjust(bottom=0,top=0.99,right=0.95,left=0.05)

# %%
plt.savefig('4s4s_trial1.png')

# %%
grounddata['basis']
# Out:
# array([[3, 2, 3, 2],
#        [3, 2, 4, 2],
#        [3, 2, 5, 2],
#        [4, 0, 4, 0],
#        [4, 0, 5, 0],
#        [4, 1, 4, 1],
#        [4, 1, 5, 1],
#        [4, 2, 4, 2],
#        [4, 2, 5, 2],
#        [4, 3, 4, 3],
#        [4, 3, 5, 3],
#        [5, 0, 5, 0],
#        [5, 1, 5, 1],
#        [5, 2, 5, 2],
#        [5, 3, 5, 3],
#        [5, 4, 5, 4]])

# %%
grounddata['V'][3]
# Out:
# array([ 0.03511583,  0.01148293, -0.00994362,  0.25137713, -0.04514966,
#        -0.08260743,  0.03504348,  0.00930758, -0.00822526, -0.00551942,
#         0.0057837 ,  0.01074352, -0.01025275,  0.00393919, -0.00308497,
#         0.00029243])

# %%
grounddata['eigvecs'][:,0]
# Out:
# array([ 5.03455527e-02,  2.56309502e-02, -1.49515634e-02, -9.32086723e-01,
#        -2.29845072e-01, -2.71471352e-01,  2.93439365e-02,  2.76502251e-03,
#        -1.79234080e-03, -2.06803491e-03,  2.14899406e-03,  1.32470237e-02,
#        -6.11992135e-03,  4.65218295e-04, -1.00384959e-03,  6.22597757e-06])

# %%
# %run LS.py

# %%
ground.VmatElement((4,0,4,0),(6,4,6,4))
# Out:
# 0.000257872845126771

# %%
ground.VmatElement((4,0,4,0),(4,2,18,2))
# Out:
# 0.000840810664219237
